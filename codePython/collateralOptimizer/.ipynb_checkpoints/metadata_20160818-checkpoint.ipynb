# %% [markdown]
# # MetaData Descriptives
# The purpose of this notebook is to extract some descriptive features of the collateral portfolio dataset which are not limited to the end-of-day price time-series.
#
# ## Objectives
# ->> Read in the data
#
# ->> Construct descriptives
#
# ->> Plot & write-up
#
# ->> Latest version:
# ```
# /Users/Dim/Desktop/school_folder/masters_thesis/gitCodeRepo/data/metaData_20160809.csv
# ```
#
# ## Suggestions
# ->> Create histogram for the rule criteria i.e. hist(last_update_date), hist(VOLUME_AVG_6M)
#
# ->> Ask Tim for a reference to the JPMorgan RiskMetrics documentation that describes the use of last_value in the case of nearby missing data

# %%
# %matplotlib inline
# coding=utf-8

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

## Set plot style to be akin to R-ggplot2
plt.style.use('ggplot')

## Read metadata .csv file
path = '/Users/Dim/Desktop/school_folder/masters_thesis/gitCodeRepo/data/metaData_20160809.csv'
df = pd.read_csv(path, sep = ';')

## Eliminate additional index variables i.e. 'MXHK Index ISIN' used for investigation 
eps = ['MXAS0IN Index ISIN', 'MXHK Index ISIN', 'MMDUAAJ Index ISIN', 'MXASJ Index ISIN', 'HKDUSD BGN Curncy ISIN']
isinVec = [set(df['BBG_ISIN'])-set(eps)]
for item in eps:
    df = df[df.BBG_ISIN != item]
    
df.head(10)
# Out:
#          SEARCH_ISIN                  BBG_ISIN                          NAME  \
# 0  AU000000RIO1 ISIN  AU000000RIO1 Equity ISIN                 RIO TINTO LTD
# 1  BE0003793107 ISIN  BE0003793107 Equity ISIN    ANHEUSER-BUSCH INBEV SA/NV
# 2  CH0011037469 ISIN  CH0011037469 Equity ISIN               SYNGENTA AG-REG
# 3  CH0011075394 ISIN  CH0011075394 Equity ISIN     ZURICH INSURANCE GROUP AG
# 4  CH0012032048 ISIN  CH0012032048 Equity ISIN  ROCHE HOLDING AG-GENUSSCHEIN
# 5  CH0012032113 ISIN  CH0012032113 Equity ISIN           ROCHE HOLDING AG-BR
# 6  CH0012221716 ISIN  CH0012221716 Equity ISIN                   ABB LTD-REG
# 7  CH0038863350 ISIN  CH0038863350 Equity ISIN                 NESTLE SA-REG
# 8  CH0244767585 ISIN  CH0244767585 Equity ISIN              UBS GROUP AG-REG
# 9  CNE1000001Q4 ISIN  CNE1000001Q4 Equity ISIN   CHINA CITIC BANK CORP LTD-H
#
#           INDUSTRY_SECTOR         INDUSTRY_SUBGROUP MKT_CAP_LAST_TRD  \
# 0         Basic Materials         Metal-Diversified      61687.57986
# 1  Consumer, Non-cyclical                   Brewery      197262.9642
# 2         Basic Materials    Agricultural Chemicals      36295.26219
# 3               Financial      Multi-line Insurance       36198.1294
# 4  Consumer, Non-cyclical             Medical-Drugs      217356.7994
# 5  Consumer, Non-cyclical             Medical-Drugs      217356.7994
# 6              Industrial   Machinery-Electric Util      47212.78767
# 7  Consumer, Non-cyclical     Food-Misc/Diversified      244827.4006
# 8               Financial  Diversified Banking Inst      52171.27127
# 9               Financial       Commer Banks Non-US      40606.84548
#
#    CUR_MKT_CAP has_large_mkt_cap has_large_mkt_cap.1 has_large_mkt_cap.2  \
# 0  61687579856                 1                   1                   1
# 1  1.97263E+11                 1                   1                   1
# 2  36295263315                 1                   0                   1
# 3  36198129212                 1                   0                   1
# 4  2.17357E+11                 1                   1                   1
# 5  2.17357E+11                 1                   1                   1
# 6  47212789530                 1                   0                   1
# 7  2.44827E+11                 1                   1                   1
# 8  52171270531                 1                   1                   1
# 9  40606845483                 1                   0                   1
#
#          ...         SECURITY_TYP CNTRY_OF_DOMICILE CRNCY LAST_UPDATE_DT  \
# 0        ...         Common Stock                GB   USD     21.07.2016
# 1        ...         Common Stock                BE   USD     08.08.2016
# 2        ...         Common Stock                CH   USD     08.08.2016
# 3        ...         Common Stock                CH   USD     05.08.2016
# 4        ...         Common Stock                CH   USD     08.08.2016
# 5        ...         Common Stock                CH   USD     08.08.2016
# 6        ...         Common Stock                CH   USD     29.07.2016
# 7        ...         Common Stock                CH   USD     08.08.2016
# 8        ...         Common Stock                CH   USD     08.08.2016
# 9        ...         Common Stock                CN   USD     25.07.2016
#
#   RTG_SP_LT_LC_ISSUER_CREDIT RTG_MDY_ISSUER VOLUME_AVG_6M CNTRY_OF_RISK  \
# 0                         A-           Baa1   151.2283478            GB
# 1                         A-            NaN   17700.62109            BE
# 2                  A+     *-          A2 *-    2689.37793            CH
# 3                        NaN            NaN   377.0157471            CH
# 4                         AA             A1    4084.70874            CH
# 5                         AA             A1   42.99212646            CH
# 6                          A             A2   41369.77344            CH
# 7                         AA            Aa2   31862.12695            CH
# 8                         A-            NaN    2893899.75            CH
# 9                        NaN            NaN   190.2362213            CN
#
#   ULT_PARENT_CNTRY_OF_RISK  GICS_SECTOR_NAME
# 0                       GB         Materials
# 1                       BE  Consumer Staples
# 2                       CH         Materials
# 3                       CH        Financials
# 4                       CH       Health Care
# 5                       CH       Health Care
# 6                       CH       Industrials
# 7                       CH  Consumer Staples
# 8                       CH        Financials
# 9                       CN        Financials
#
# [10 rows x 21 columns]

# %%
## Extracting descriptive information 
colNames = pd.DataFrame(df.columns)

## Descriptives
# Function getCounts: used to obtain counts for various items in meta-data
# @param col: column name
# @param setX: a set containing unique attributes under the column name, as above
# @param df: the dataframe from which to extract the information 
def getCounts(col, setX, df):
    a = pd.DataFrame({'Identifier' : [], 
                      'Count' : []})
    for item in setX:
        count = sum(df[col] == item)
        a = a.append(pd.DataFrame({'Identifier' : [item], 
                                   'Count' : [count]}), ignore_index = True)
    return a

# Create a placeholder list & select items of interest from mnemonics
frames = []
names  = ['INDUSTRY_SECTOR', 'INDUSTRY_SUBGROUP', 'GICS_SECTOR_NAME', 'CRNCY', 'CNTRY_OF_DOMICILE', 'CNTRY_OF_RISK']

# Populate count information
for name in names:
    a = getCounts(col = name, setX = set(df[name]), df = df)
    a = a.set_index(a.Identifier)
    a = a.drop('Identifier', axis = 1)
    a.index.name = name
    frames.append(a)

# Plot count information 
for i in frames:
    i.plot(kind='bar', figsize=(9,9), colormap='spectral'); plt.axhline(0, color='k')

# %%
namesStacked = ['RTG_SP_LT_LC_ISSUER_CREDIT', 'RTG_MDY_ISSUER']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-130-edbe3cfa495d> in <module>()
#       1 namesStacked = ['RTG_SP_LT_LC_ISSUER_CREDIT', 'RTG_MDY_ISSUER']
# ----> 2 frames[namesStacked]
#
# TypeError: list indices must be integers, not list

# %%
def getSubCounts(col1, col2, setX, setY, df):
    bucket = []
    for item1 in setX:
        container = []
        for item2 in setY:
            one = (df[col1] == item1)
            two = (df[col2] == item2)
            count = sum(np.logical_and(one, two))
            a = {'item1': item1, 'item2': item2, 'count': count}
            container.append(a)
        bucket.append(container)
    return bucket

crossTable_country_rating = getSubCounts('CNTRY_OF_DOMICILE', 
                                         'RTG_MDY_ISSUER', 
                                         setX = set(df['CNTRY_OF_DOMICILE']), 
                                         setY = set(df['RTG_MDY_ISSUER']), 
                                         df = df)

crossTable_countr_sector = getSubCounts('CNTRY_OF_DOMICILE', 
                                        'INDUSTRY_SECTOR', 
                                        setX=set(df['CNTRY_OF_DOMICILE']), 
                                        setY=set(df['INDUSTRY_SECTOR']), 
                                        df = df)

# %%
bucket = pd.DataFrame()
for item in crossTable_country_rating:
    frame = pd.DataFrame(item)
    frame = frame.set_index(frame.item2)
    frame.rename(columns={'count':frame.item1.unique()[0]}, inplace=True)
    frame.index.name = 'RTG_MDY_ISSUER'
    frame = frame.drop(['item1', 'item2'], axis=1)
    #frame.transpose().plot(kind='bar', stacked=True)
    frame = frame.transpose()
    bucket = bucket.append(frame) 

bucket.plot(kind='bar', stacked=True, figsize=(18,9), colormap='viridis'); plt.axhline(0, color='k')

bucket = pd.DataFrame()
for item in crossTable_countr_sector:
    frame = pd.DataFrame(item)
    frame = frame.set_index(frame.item2)
    frame.rename(columns={'count':frame.item1.unique()[0]}, inplace=True)
    frame.index.name = 'INDUSTRY_SECTOR'
    frame = frame.drop(['item1', 'item2'], axis=1)
    #frame.transpose().plot(kind='bar', stacked=True)
    frame = frame.transpose()
    bucket = bucket.append(frame) 

bucket.plot(kind='bar', stacked=True, figsize=(18,9), colormap='viridis'); plt.axhline(0, color='k')

# %%
frame = pd.DataFrame(test[1])
frame = frame.set_index(frame.item2)
frame.rename(columns={'count':frame.item1.unique()[0]}, inplace=True)
frame.index.name = 'RTG_MDY_ISSUER'
frame = frame.drop(['item1', 'item2'], axis=1)
frame.transpose().plot(kind='bar', stacked=True)
frame.transpose()
# Out:
# RTG_MDY_ISSUER  NaN  Ba1  Baa1  Baa3  A1  A2 *-  A3  A2  WR  Aa3  Aa2
# FR                0    0     0     0   2      0   1   0   0    0    0
